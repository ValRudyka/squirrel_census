# %% [markdown]
# Analyzing squirrel census data in New York, 2018

# %%
import pandas as pd
import sqlalchemy
import csv

import re
from dotenv import load_dotenv
import os

load_dotenv()

# cleaning data received from csv file
data = []
header = None
with open(os.getenv('FILE'), 'r', encoding='utf-8') as file:
        reader = csv.reader(file, delimiter=',', quotechar='"', escapechar='\\')
        
        header = next(reader)
        
        for row in reader:
            if len(row) == 1:
                row_data = row[0]
                row = re.split(r',(?![^"]*"(?:[^"]*"[^"]*")*[^"]*$)', row_data)
            
            data.append(row)
                
# preparations
squirrel_df = pd.DataFrame(data, columns=header)
engine = sqlalchemy.create_engine(os.getenv('POSTGRES_URL'))

squirrel_df.head()
# Out:
#                       X                 Y unique_squirrel_id hectare shift  \
# 0     -73.9561344937861  40.7940823884086     37F-PM-1014-03     37F    PM
# 1     -73.9688574691102  40.7837825208444     21B-AM-1019-04     21B    AM
# 2     -73.9742811484852   40.775533619083     11B-PM-1014-08     11B    PM
# 3     -73.9596413903948  40.7903128889029     32E-PM-1017-14     32E    PM
# 4     -73.9702676472613  40.7762126854894     13E-AM-1017-05     13E    AM
# ...                 ...               ...                ...     ...   ...
# 3018  -73.9639431360458  40.7908677445466     30B-AM-1007-04     30B    AM
# 3019  -73.9704015859639  40.7825600069973     19A-PM-1013-05     19A    PM
# 3020  -73.9665871993517  40.7836775064883     22D-PM-1012-07     22D    PM
# 3021  -73.9639941227864  40.7899152327912     29B-PM-1010-02     29B    PM
# 3022  -73.9754794191553  40.7696404489025      5E-PM-1012-01     05E    PM
#
#           date hectare_squirrel_number    age primary_fur_color  \
# ...

# %%
# connecting to postgres db
# %load_ext sql
# %sql $engine.url
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: postgres@squirrel_data'

# %%
# saving the data into sql table
squirrel_df.to_sql('squirrels', engine, if_exists='replace')
# Out:
# 23
