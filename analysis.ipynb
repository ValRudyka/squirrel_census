# %% [markdown]
# Answering on several questions about our data

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:KevSu15E@localhost/squirrel_data

# %% [markdown]
# Question 1: Calculate squirrels population for each location. Then, determine which area has high population density.
# To achieve this, assume that an area has a high population density if its population is greater than the average,
# and a low density if it is below the average.

# %%
# %%sql
# WITH populations AS (
#     SELECT
#         l.location,
#         COUNT(s.unique_squirrel_id) AS population
#     FROM squirrels AS s
#     INNER JOIN locations AS l
#     ON s.unique_squirrel_id = l.unique_squirrel_id
#     GROUP BY l.location
# )
#
# SELECT
#     l.hectare,
#     l.specific_location,
#     l.location,
#     p.population,
#     CASE WHEN p.population >= (SELECT AVG(population) FROM populations) THEN 'High density'
#             ELSE 'Low density' END AS is_dense
# FROM locations AS l
# INNER JOIN populations AS p
# ON l.location = p.location
# LIMIT 200;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 200 rows affected.
# [('11B', None, 'Above Ground', 843, 'Low density'),
#  ('13E', 'on tree stump', 'Above Ground', 843, 'Low density'),
#  ('36H', None, 'Ground Plane', 2126, 'High density'),
#  ('33F', None, 'Ground Plane', 2126, 'High density'),
#  ('21C', None, 'Ground Plane', 2126, 'High density'),
#  ('11D', None, 'Above Ground', 843, 'Low density'),
#  ('20B', None, 'Ground Plane', 2126, 'High density'),
#  ('22F', None, 'Ground Plane', 2126, 'High density'),
#  ('36I', None, 'Ground Plane', 2126, 'High density'),
#  ('05C', None, 'Ground Plane', 2126, 'High density'),
#  ('07H', None, 'Above Ground', 843, 'Low density'),
#  ('16C', None, 'Above Ground', 843, 'Low density'),
#  ('14E', None, 'Ground Plane', 2126, 'High density'),
#  ('32A', None, 'Ground Plane', 2126, 'High density'),
#  ('33F', None, 'Ground Plane', 2126, 'High density'),
#  ('17F', None, 'Above Ground', 843, 'Low density'),
#  ('16I', None, 'Ground Plane', 2126, 'High density'),
#  ('12I', 'on tree roots', 'Ground Plane', 2126, 'High density'),
#  ('32F', None, 'Ground Plane', 2126, 'High density'),
#  ('25A', None, 'Ground Plane', 2126, 'High density'),
#  ('15E', None, 'Ground Plane', 2126, 'High density'),
#  ('39G', None, 'Ground Plane', 2126, 'High density'),
#  ('29I', None, 'Ground Plane', 2126, 'High density'),
#  ('07E', 'under a tree', 'Ground Plane', 2126, 'High density'),
#  ('17C', None, 'Ground Plane', 2126, 'High density'),
#  ('10A', 'in b/w trees', 'Ground Plane', 2126, 'High density'),
#  ('28A', None, 'Ground Plane', 2126, 'High density'),
#  ('22F', None, 'Ground Plane', 2126, 'High density'),
#  ('12B', None, 'Ground Plane', 2126, 'High density'),
#  ('18A', None, 'Above Ground', 843, 'Low density'),
#  ('33H', None, 'Ground Plane', 2126, 'High density'),
#  ('36H', None, 'Ground Plane', 2126, 'High density'),
#  ('29C', None, 'Ground Plane', 2126, 'High density'),
#  ('38C', None, 'Ground Plane', 2126, 'High density'),
#  ('31H', None, 'Above Ground', 843, 'Low density'),
#  ('08H', None, 'Above Ground', 843, 'Low density'),
#  ('34F', None, 'Above Ground', 843, 'Low density'),
#  ('13H', 'tree', 'Above Ground', 843, 'Low density'),
#  ('32E', None, 'Above Ground', 843, 'Low density'),
#  ('35C', None, 'Above Ground', 843, 'Low density'),
#  ('35C', None, 'Ground Plane', 2126, 'High density'),
#  ('17E', 'Branch', 'Above Ground', 843, 'Low density'),
#  ('02B', None, 'Ground Plane', 2126, 'High density'),
#  ('19D', None, 'Ground Plane', 2126, 'High density'),
#  ('40B', None, 'Ground Plane', 2126, 'High density'),
#  ('03E', None, 'Ground Plane', 2126, 'High density'),
#  ('39C', None, 'Ground Plane', 2126, 'High density'),
#  ('06G', 'bush', 'Ground Plane', 2126, 'High density'),
#  ('14F', None, 'Ground Plane', 2126, 'High density'),
#  ('06I', None, 'Ground Plane', 2126, 'High density'),
#  ('15F', None, 'Ground Plane', 2126, 'High density'),
#  ('08B', 'hiding in bushes', 'Ground Plane', 2126, 'High density'),
#  ('03A', None, 'Ground Plane', 2126, 'High density'),
#  ('36I', None, 'Ground Plane', 2126, 'High density'),
#  ('05E', None, 'Ground Plane', 2126, 'High density'),
#  ('05F', None, 'Ground Plane', 2126, 'High density'),
#  ('11B', None, 'Ground Plane', 2126, 'High density'),
#  ('16E', 'On a rock', 'Ground Plane', 2126, 'High density'),
#  ('20B', None, 'Ground Plane', 2126, 'High density'),
#  ('03A', None, 'Ground Plane', 2126, 'High density'),
#  ('29H', None, 'Above Ground', 843, 'Low density'),
#  ('23C', None, 'Above Ground', 843, 'Low density'),
#  ('33C', None, 'Ground Plane', 2126, 'High density'),
#  ('38G', None, 'Ground Plane', 2126, 'High density'),
#  ('16G', None, 'Ground Plane', 2126, 'High density'),
#  ('36I', None, 'Ground Plane', 2126, 'High density'),
#  ('35A', None, 'Ground Plane', 2126, 'High density'),
#  ('28C', None, 'Ground Plane', 2126, 'High density'),
#  ('32D', None, 'Ground Plane', 2126, 'High density'),
#  ('22A', 'trash can', 'Above Ground', 843, 'Low density'),
#  ('40B', None, 'Ground Plane', 2126, 'High density'),
#  ('19C', None, 'Ground Plane', 2126, 'High density'),
#  ('35A', None, 'Ground Plane', 2126, 'High density'),
#  ('14E', None, 'Ground Plane', 2126, 'High density'),
#  ('15G', None, 'Above Ground', 843, 'Low density'),
#  ('10F', None, 'Above Ground', 843, 'Low density'),
#  ('42E', None, 'Ground Plane', 2126, 'High density'),
#  ('22B', 'Under bench', 'Ground Plane', 2126, 'High density'),
#  ('15F', None, 'Ground Plane', 2126, 'High density'),
#  ('05A', 'near 65th St arch', 'Ground Plane', 2126, 'High density'),
#  ('32H', 'in the European Beech', 'Above Ground', 843, 'Low density'),
#  ('41D', None, 'Ground Plane', 2126, 'High density'),
#  ('21G', None, 'Ground Plane', 2126, 'High density'),
#  ('14E', None, 'Ground Plane', 2126, 'High density'),
#  ('07H', 'on tree knob', 'Above Ground', 843, 'Low density'),
#  ('22F', None, 'Ground Plane', 2126, 'High density'),
#  ('07F', 'tree', 'Above Ground', 843, 'Low density'),
#  ('10F', 'Behind fence, tree', 'Above Ground', 843, 'Low density'),
#  ('10A', 'tree near large rock on Bridle Path', 'Above Ground', 843, 'Low density'),
#  ('38F', None, 'Ground Plane', 2126, 'High density'),
#  ('41B', 'Climbing tree', 'Above Ground', 843, 'Low density'),
#  ('36A', '"FIELD"', 'Ground Plane', 2126, 'High density'),
#  ('05C', None, 'Ground Plane', 2126, 'High density'),
#  ('32E', 'bottom of tree', 'Above Ground', 843, 'Low density'),
#  ('31A', None, 'Ground Plane', 2126, 'High density'),
#  ('42G', None, 'Ground Plane', 2126, 'High density'),
#  ('37D', None, 'Ground Plane', 2126, 'High density'),
#  ('37E', None, 'Ground Plane', 2126, 'High density'),
#  ('24B', None, 'Above Ground', 843, 'Low density'),
#  ('07G', None, 'Above Ground', 843, 'Low density'),
#  ('05C', 'way up a tree!', 'Above Ground', 843, 'Low density'),
#  ('15I', 'tree', 'Above Ground', 843, 'Low density'),
#  ('19B', None, 'Above Ground', 843, 'Low density'),
#  ('13D', None, 'Ground Plane', 2126, 'High density'),
#  ('36I', None, 'Ground Plane', 2126, 'High density'),
#  ('41B', None, 'Above Ground', 843, 'Low density'),
#  ('35B', 'lawn', 'Ground Plane', 2126, 'High density'),
#  ('40D', None, 'Ground Plane', 2126, 'High density'),
#  ('38B', None, 'Ground Plane', 2126, 'High density'),
#  ('40I', None, 'Ground Plane', 2126, 'High density'),
#  ('07B', None, 'Ground Plane', 2126, 'High density'),
#  ('13D', None, 'Ground Plane', 2126, 'High density'),
#  ('16G', None, 'Ground Plane', 2126, 'High density'),
#  ('40A', 'bottom of great hill', 'Ground Plane', 2126, 'High density'),
#  ('15I', None, 'Ground Plane', 2126, 'High density'),
#  ('03B', 'in tree', 'Above Ground', 843, 'Low density'),
#  ('21D', None, 'Ground Plane', 2126, 'High density'),
#  ('10B', None, 'Ground Plane', 2126, 'High density'),
#  ('13E', None, 'Ground Plane', 2126, 'High density'),
#  ('41A', None, 'Ground Plane', 2126, 'High density'),
#  ('02F', None, 'Ground Plane', 2126, 'High density'),
#  ('20B', None, 'Ground Plane', 2126, 'High density'),
#  ('26A', 'Tree 90th left 90th & 89', 'Ground Plane', 2126, 'High density'),
#  ('35E', None, 'Ground Plane', 2126, 'High density'),
#  ('11G', 'In the Woods/Brush', 'Above Ground', 843, 'Low density'),
#  ('36I', None, 'Ground Plane', 2126, 'High density'),
#  ('07A', 'in tree', 'Above Ground', 843, 'Low density'),
#  ('07G', None, 'Ground Plane', 2126, 'High density'),
#  ('14E', None, 'Above Ground', 843, 'Low density'),
#  ('03D', None, 'Ground Plane', 2126, 'High density'),
#  ('35D', None, 'Ground Plane', 2126, 'High density'),
#  ('07F', None, 'Ground Plane', 2126, 'High density'),
#  ('18G', None, 'Ground Plane', 2126, 'High density'),
#  ('06F', None, 'Above Ground', 843, 'Low density'),
#  ('09F', None, 'Ground Plane', 2126, 'High density'),
#  ('38E', None, 'Ground Plane', 2126, 'High density'),
#  ('33G', 'shelter in hole in tree', 'Above Ground', 843, 'Low density'),
#  ('39G', None, 'Ground Plane', 2126, 'High density'),
#  ('32G', None, 'Ground Plane', 2126, 'High density'),
#  ('04D', 'on tree facing downward', 'Above Ground', 843, 'Low density'),
#  ('06H', None, 'Ground Plane', 2126, 'High density'),
#  ('05E', None, 'Ground Plane', 2126, 'High density'),
#  ('15D', None, 'Ground Plane', 2126, 'High density'),
#  ('16E', None, 'Ground Plane', 2126, 'High density'),
#  ('39H', None, 'Ground Plane', 2126, 'High density'),
#  ('39C', None, 'Above Ground', 843, 'Low density'),
#  ('31A', None, 'Ground Plane', 2126, 'High density'),
#  ('09F', None, 'Ground Plane', 2126, 'High density'),
#  ('21G', None, 'Ground Plane', 2126, 'High density'),
#  ('02F', 'walking along path', 'Ground Plane', 2126, 'High density'),
#  ('20F', None, 'Ground Plane', 2126, 'High density'),
#  ('35E', None, 'Ground Plane', 2126, 'High density'),
#  ('09G', None, 'Above Ground', 843, 'Low density'),
#  ('05D', None, 'Ground Plane', 2126, 'High density'),
#  ('14F', None, 'Ground Plane', 2126, 'High density'),
#  ('23F', None, 'Above Ground', 843, 'Low density'),
#  ('39A', None, 'Ground Plane', 2126, 'High density'),
#  ('13A', None, 'Above Ground', 843, 'Low density'),
#  ('10B', 'High in a tree', 'Above Ground', 843, 'Low density'),
#  ('38B', None, 'Ground Plane', 2126, 'High density'),
#  ('09G', None, 'Ground Plane', 2126, 'High density'),
#  ('40B', None, 'Ground Plane', 2126, 'High density'),
#  ('10G', None, 'Ground Plane', 2126, 'High density'),
#  ('13C', None, 'Ground Plane', 2126, 'High density'),
#  ('32C', None, 'Ground Plane', 2126, 'High density'),
#  ('37F', None, 'Ground Plane', 2126, 'High density'),
#  ('31D', None, 'Above Ground', 843, 'Low density'),
#  ('15I', None, 'Ground Plane', 2126, 'High density'),
#  ('19C', None, 'Ground Plane', 2126, 'High density'),
#  ('10F', None, 'Ground Plane', 2126, 'High density'),
#  ('18C', None, 'Ground Plane', 2126, 'High density'),
#  ('07B', None, 'Ground Plane', 2126, 'High density'),
#  ('40E', None, 'Ground Plane', 2126, 'High density'),
#  ('38B', None, 'Above Ground', 843, 'Low density'),
#  ('03B', None, 'Ground Plane', 2126, 'High density'),
#  ('19B', None, 'Ground Plane', 2126, 'High density'),
#  ('41B', None, 'Above Ground', 843, 'Low density'),
#  ('04G', 'tree', 'Above Ground', 843, 'Low density'),
#  ('12F', None, 'Ground Plane', 2126, 'High density'),
#  ('03B', None, 'Above Ground', 843, 'Low density'),
#  ('17H', None, 'Ground Plane', 2126, 'High density'),
#  ('38G', None, 'Ground Plane', 2126, 'High density'),
#  ('04D', None, 'Ground Plane', 2126, 'High density'),
#  ('03G', None, 'Ground Plane', 2126, 'High density'),
#  ('15H', 'lawn moving east over Park path', 'Ground Plane', 2126, 'High density'),
#  ('14G', None, 'Ground Plane', 2126, 'High density'),
#  ('05D', None, 'Above Ground', 843, 'Low density'),
#  ('05C', None, 'Above Ground', 843, 'Low density'),
#  ('42H', None, 'Ground Plane', 2126, 'High density'),
#  ('38A', None, 'Above Ground', 843, 'Low density'),
#  ('07G', None, 'Ground Plane', 2126, 'High density'),
#  ('31A', None, 'Ground Plane', 2126, 'High density'),
#  ('22C', None, 'Ground Plane', 2126, 'High density'),
#  ('36F', None, 'Ground Plane', 2126, 'High density'),
#  ('05C', None, 'Above Ground', 843, 'Low density'),
#  ('13H', None, 'Ground Plane', 2126, 'High density'),
#  ('10F', 'Behind fence, grass', 'Ground Plane', 2126, 'High density'),
#  ('05I', 'in tree by arsenal - climbing', 'Above Ground', 843, 'Low density'),
#  ('16D', None, 'Ground Plane', 2126, 'High density'),
#  ('21G', None, 'Above Ground', 843, 'Low density')]

# %% [markdown]
# Adding the same column to grouped table help us to determine  better which location has high or low density.

# %%
# %%sql
# WITH populations AS (
#     SELECT
#         l.location,
#         COUNT(s.unique_squirrel_id) AS population
#     FROM squirrels AS s
#     INNER JOIN locations AS l
#     ON s.unique_squirrel_id = l.unique_squirrel_id
#     GROUP BY l.location
# )
#
# SELECT
#     location,
#     population,
#     CASE WHEN population >= (SELECT AVG(population) FROM populations) THEN 'High density'
#             ELSE 'Low density' END AS is_dense
# FROM populations;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 3 rows affected.
# [(None, 64, 'Low density'),
#  ('Ground Plane', 2126, 'High density'),
#  ('Above Ground', 843, 'Low density')]

# %% [markdown]
# Question 2: What are the ages and colours of squirrels displaying vocal behaviors around Strawberry Fields in Central Park?

# %%
# %%sql
# SELECT
#     s.age,
#     s.primary_fur_color,
#     b.kuks,
#     b.quaas,
#     b.moans,
#     l.hectare
# FROM squirrels AS s
#     INNER JOIN behaviors AS b
#     ON s.unique_squirrel_id = b.unique_squirrel_id
#     INNER JOIN locations AS l
#     ON s.unique_squirrel_id = l.unique_squirrel_id
# WHERE l.hectare IN ('30B', '31B')
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 28 rows affected.
# [('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Juvenile', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B'),
#  ('Juvenile', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '31B'),
#  ('Adult', 'Gray', False, False, False, '30B')]

# %% [markdown]
# We see that adults more tend to display vocal behaviours.
#
# Question 3: What are the primary fur color of squirrels displaying the vocal behavior 'moans' or another behavior 'tail flags'

# %%
# %%sql
# SELECT
#     s.primary_fur_color,
#     s.age,
#     l.location,
#     COUNT(s.unique_squirrel_id) AS squirrel_count,
#     CASE WHEN (b.moans = True) THEN 'Moaning'
#         ELSE 'Tailing flags' END AS behavior
# FROM squirrels AS s
#     INNER JOIN behaviors AS b
#     ON s.unique_squirrel_id = b.unique_squirrel_id
#     INNER JOIN locations AS l
#     ON s.unique_squirrel_id = l.unique_squirrel_id
# WHERE (b.moans = True) OR (b.tail_flags = True)
# GROUP BY s.primary_fur_color, s.age, l.location, behavior
# ORDER BY squirrel_count DESC;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 16 rows affected.
# [('Gray', 'Adult', 'Ground Plane', 82, 'Tailing flags'),
#  ('Gray', 'Adult', 'Above Ground', 23, 'Tailing flags'),
#  ('Cinnamon', 'Adult', 'Above Ground', 11, 'Tailing flags'),
#  ('Gray', 'Juvenile', 'Ground Plane', 10, 'Tailing flags'),
#  ('Cinnamon', 'Juvenile', 'Ground Plane', 7, 'Tailing flags'),
#  ('Cinnamon', 'Adult', 'Ground Plane', 7, 'Tailing flags'),
#  ('Black', 'Adult', 'Ground Plane', 4, 'Tailing flags'),
#  ('Gray', None, 'Ground Plane', 3, 'Tailing flags'),
#  ('Gray', None, 'Above Ground', 3, 'Tailing flags'),
#  ('Black', 'Adult', 'Above Ground', 2, 'Tailing flags'),
#  (None, 'Adult', 'Above Ground', 1, 'Tailing flags'),
#  (None, 'Adult', 'Above Ground', 1, 'Moaning'),
#  ('Cinnamon', 'Juvenile', 'Above Ground', 1, 'Tailing flags'),
#  ('Gray', None, 'Above Ground', 1, 'Moaning'),
#  ('Gray', 'Adult', 'Above Ground', 1, 'Moaning'),
#  ('Gray', 'Juvenile', 'Above Ground', 1, 'Tailing flags')]

# %% [markdown]
# From the result above, squirrels mostly display tail-flagging behavior instead of moaning (there are single cases for all ages and other
# group categories). Gray fur color is the most common in observing tail-flagging behavior.
#
# Question 4: calculate the percentage of squirrels displaying the activities like running, chasing and climbing based on shift and location (firstly calculate for each shift and location separately, then merge this categories )

# %%
# %%sql
# SELECT
#     s.shift,
#     ROUND(AVG(b.running::integer), 3) AS run_percentage,
#     ROUND(AVG(b.chasing::integer), 3)  AS chase_percentage,
#     ROUND(AVG(b.climbing::integer), 3)  AS climb_percentage
# FROM squirrels AS s
#     INNER JOIN behaviors AS b
#     ON s.unique_squirrel_id = b.unique_squirrel_id
# GROUP BY s.shift;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 2 rows affected.
# [('PM', Decimal('0.243'), Decimal('0.088'), Decimal('0.189')),
#  ('AM', Decimal('0.242'), Decimal('0.097'), Decimal('0.252'))]

# %%
# %%sql
# SELECT
#     l.location,
#     ROUND(AVG(b.running::integer), 3) AS run_percentage,
#     ROUND(AVG(b.chasing::integer), 3)  AS chase_percentage,
#     ROUND(AVG(b.climbing::integer), 3)  AS climb_percentage
# FROM behaviors AS b
#     INNER JOIN locations AS l
#     ON b.unique_squirrel_id = l.unique_squirrel_id
# GROUP BY l.location;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 3 rows affected.
# [(None, Decimal('0.109'), Decimal('0.063'), Decimal('0.031')),
#  ('Ground Plane', Decimal('0.265'), Decimal('0.082'), Decimal('0.064')),
#  ('Above Ground', Decimal('0.196'), Decimal('0.120'), Decimal('0.617'))]

# %%
# %%sql
# SELECT
#     s.shift,
#     l.location,
#     ROUND(AVG(b.running::integer), 3) AS run_percentage,
#     ROUND(AVG(b.chasing::integer), 3)  AS chase_percentage,
#     ROUND(AVG(b.climbing::integer), 3)  AS climb_percentage
# FROM squirrels AS s
#     INNER JOIN locations AS l
#     ON s.unique_squirrel_id = l.unique_squirrel_id
#     INNER JOIN behaviors AS b
#     ON s.unique_squirrel_id = b.unique_squirrel_id
# GROUP BY s.shift, l.location;
# Out:
#  * postgresql://postgres:***@localhost/squirrel_data
# 6 rows affected.
# [('PM', 'Above Ground', Decimal('0.195'), Decimal('0.122'), Decimal('0.594')),
#  ('PM', 'Ground Plane', Decimal('0.269'), Decimal('0.079'), Decimal('0.066')),
#  ('AM', 'Above Ground', Decimal('0.196'), Decimal('0.118'), Decimal('0.637')),
#  ('PM', None, Decimal('0.122'), Decimal('0.024'), Decimal('0.024')),
#  ('AM', 'Ground Plane', Decimal('0.267'), Decimal('0.085'), Decimal('0.060')),
#  ('AM', None, Decimal('0.087'), Decimal('0.130'), Decimal('0.043'))]

# %% [markdown]
# Despite a slight advantage in the evening dimension of squirrels' mobility, they tend to be more active in the daytime than in the evening. As for location, the most intensive squirrels are from Ground Plane.
